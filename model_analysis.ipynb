# %% [markdown]
# # Imports

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Code

# %% [markdown]
# - If training loss decreases but validation loss increases, the model is overfitting.
# - If both are high, model is underfitting
# - If both decrease steadily, training thats good.

# %%
# =========================
# PLOT TRAINING LOSS
# =========================

plt.figure(figsize=(8, 5))

loss = history.history['loss']
validation_loss = history.history['val_loss']

plt.plot(loss.history['loss'], label='Training Loss')
plt.plot(validation_loss, label='Validation Loss')

plt.title('Model Loss per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6775/147540096.py in <cell line: 0>()
#       7 plt.figure(figsize=(8, 5))
#       8
# ----> 9 plt.plot(history.history['loss'], label='Training Loss')
#      10 plt.plot(history.history['val_loss'], label='Validation Loss')
#      11
#
# NameError: name 'history' is not defined

# %% [markdown]
# Visualising Cross-Entropy Loss per Epoch

# %%
plt.plot(range(1, len(loss) + 1), loss, 'o--')
plt.xlabel('Epoch Number')
plt.ylabel('Cross Entropy')
plt.title('Cross Entropy Loss per Epoch')
plt.show()

# %% [markdown]
# Sample image with a label and prediction

# %%
x_sample, y_sample = next(iter(val_data))

x_sample = x_sample[0]
y_sample = y_sample[0]

yhat_sample = model.predict(np.expand_dims(x_sample, axis=0))

print("True label:", np.argmax(y_sample))
print("Predicted label:", np.argmax(yhat_sample))

plt.imshow(x_sample)
plt.axis('off')
plt.show()

# %% [markdown]
# Class names instead of numbers (could be useful but not sure)

# %%
class_names = list(train_data.class_indices.keys())

print("True label:", class_names[np.argmax(y_sample)])
print("Predicted label:", class_names[np.argmax(yhat_sample)])
